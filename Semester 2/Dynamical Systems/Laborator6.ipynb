# %%
t=var('t')
s=var('s')
x=function('x')(t)
f=function('f')(s)
f(s)=s^2-2*s
eq=solve(f(s)==0,s)
eq
# Out:
# [s == 0, s == 2]

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3,headlength=4,color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq, x, [0,-1], step=0.01, end_points=[-5,5], output='plot', color='blue')
g2=desolve_rk4(deq, x, [0, 0], step=0.01, end_points=[-5,5], output='plot', color='black')
g3=desolve_rk4(deq, x, [0, 1], step=0.01, end_points=[-5,5], output='plot', color='blue')
g4=desolve_rk4(deq, x, [0, 2], step=0.01, end_points=[-5,5], output='plot', color='black')
g5=desolve_rk4(deq, x, [0, 3], step=0.01, end_points=[-5,5], output='plot', color='blue')
g=sf+g1+g2+g3+g4+g5
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
f(s)=s*(s-1)*(s-2)
eq=solve(f(s)==0,s)
eq
# Out:
# [s == 0, s == 1, s == 2]

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3,headlength=4,color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq, x, [0,-0.5], step=0.01, end_points=[-5,5], output='plot', color='blue')
g2=desolve_rk4(deq, x, [0, 0], step=0.01, end_points=[-5,5], output='plot', color='black')
g3=desolve_rk4(deq, x, [0, 0.5], step=0.01, end_points=[-5,5], output='plot', color='blue')
g4=desolve_rk4(deq, x, [0, 1], step=0.01, end_points=[-5,5], output='plot', color='black')
g5=desolve_rk4(deq, x, [0, 1.5], step=0.01, end_points=[-5,5], output='plot', color='blue')
g6=desolve_rk4(deq, x, [0, 2], step=0.01, end_points=[-5,5], output='plot', color='black')
g7=desolve_rk4(deq, x, [0, 2.5], step=0.01, end_points=[-5,5], output='plot', color='blue')
g=sf+g1+g2+g3+g4+g5+g6+g7
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
reset()
t=var('t')
s=var('s')
x=function('x')(t)
f=function('f')(s)
f(s)=sin(s)
eq=solve(f(s)==0,s,to_poly_solve='force')
eq
# Out:
# [s == pi*z5]

# %%
sf=plot_slope_field(f(s),(t,-10,10),(s,-10,10),headaxislength=5,headlength=10,color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq, x, [0,numerical_approx(-pi)], step=0.01, end_points=[-10,10], output='plot', color='blue')
g2=desolve_rk4(deq, x, [0, -1.5], step=0.01, end_points=[-10,10], output='plot', color='black')
g3=desolve_rk4(deq, x, [0, 0], step=0.01, end_points=[-10,10], output='plot', color='blue')
g4=desolve_rk4(deq, x, [0, 1.5], step=0.01, end_points=[-10,10], output='plot', color='black')
g5=desolve_rk4(deq, x, [0, numerical_approx(pi)], step=0.01, end_points=[-10,10], output='plot', color='blue')
g6=desolve_rk4(deq, x, [0, 4.5], step=0.01, end_points=[-10,10], output='plot', color='black')
g7=desolve_rk4(deq, x, [0, numerical_approx(2*pi)], step=0.01, end_points=[-10,10], output='plot', color='blue')
g8=desolve_rk4(deq, x, [0, 7.5], step=0.01, end_points=[-10,10], output='plot', color='black')
g9=desolve_rk4(deq, x, [0, numerical_approx(3*pi)], step=0.01, end_points=[-10,10], output='plot', color='blue')
g=sf+g1+g2+g3+g4+g5+g6+g7+g8+g9
g.show(ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
reset()
x,y,t=var('x,y,t')
f1=function('f1')(x,y)
f2=function('f2')(x,y)
f1(x,y)=2*x+y
f2(x,y)=x+2*y

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
list_plot(XY, plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5], color='red', aspect_ratio=1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
reset()
x,y,t=var('x,y,t')
f1=function('f1')(x,y)
f2=function('f2')(x,y)
f1(x,y)=-y
f2(x,y)=x

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
list_plot(XY, plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5], color='red', aspect_ratio=1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
reset()
x,y,t=var('x,y,t')
f1=function('f1')(x,y)
f2=function('f2')(x,y)
f1(x,y)=-x-y
f2(x,y)=x-3*y

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
list_plot(XY, plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5], color='red', aspect_ratio=1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-1,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,-2,0], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-1], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics=[0,0,-2], ivar=t, end_points=[-1,1],step=0.1)
XY=[ [j,k] for i,j,k in P]
g=g+list_plot(XY, plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives
